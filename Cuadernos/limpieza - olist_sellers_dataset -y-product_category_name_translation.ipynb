# %% [markdown]
# #Limpieza de datos:

# %%
import pandas as pd

# %% [markdown]
# Importacion de archivo: "olist_sellers_dataset --act.csv"

# %%
df=pd.read_csv("olist_sellers_dataset --act.csv")
df
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %% [markdown]
# Importacion de archivo: "product_category_name_translation--act.csv"

# %%
df2=pd.read_csv("product_category_name_translation--act.csv")
df2
# Out:
#             product_category_name nombre_categoría_producto_ español
# 0                    beleza_saude                      belleza_salud
# 1          informatica_acessorios            accesorios_informáticos
# 2                      automotivo                               auto
# 3                 cama_mesa_banho                     cama_mesa_baño
# 4                moveis_decoracao                 muebles_decoración
# ..                            ...                                ...
# 66                         flores                             flores
# 67             artes_e_artesanato                       manualidades
# 68                fraldas_higiene                    pañales_higiene
# 69  fashion_roupa_infanto_juvenil                    moda_para_niños
# 70             seguros_e_servicos                seguros_y_servicios
#
# [71 rows x 2 columns]

# %% [markdown]
# Ver las variables categóricas y las numéricas:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   product_category_name               71 non-null     object
#  1   nombre_categoría_producto_ español  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# Datos faltantes:

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
df2.dropna(inplace=True)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   product_category_name               71 non-null     object
#  1   nombre_categoría_producto_ español  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# Filas repetidas

# %%
print(f'Tamaño del set antes de eliminar las filas repetidas: {df.shape}')
df.drop_duplicates(inplace=True)
print(f'Tamaño del set después de eliminar las filas repetidas: {df.shape}')
# Out:
# Tamaño del set antes de eliminar las filas repetidas: (3095, 4)
# Tamaño del set después de eliminar las filas repetidas: (3095, 4)

# %%
print(f'Tamaño del set antes de eliminar las filas repetidas: {df2.shape}')
df2.drop_duplicates(inplace=True)
print(f'Tamaño del set después de eliminar las filas repetidas: {df2.shape}')
# Out:
# Tamaño del set antes de eliminar las filas repetidas: (71, 2)
# Tamaño del set después de eliminar las filas repetidas: (71, 2)
